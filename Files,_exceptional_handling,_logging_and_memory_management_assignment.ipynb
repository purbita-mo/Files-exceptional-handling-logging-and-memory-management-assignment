# %% [markdown]
# 1. HF What is the difference between interpreted and compiled languages0
#
# A. Interpreted:
# Code is translated line-by-line during execution.
# Slower execution compared to compiled languages.
# Easier to debug as you can see the code as it runs.
# Good for rapid prototyping and development.
#
# Compiled:
# Code is translated into machine code once before running.
# Faster execution.
# May require a separate compilation step.
# Can be more complex to debug.
#
# 2.  What is exception handling in Python?
#
# In python an exception is an event that occurs during programme execution that disrupts the regular flow of code. Exception handling is a critical aspect of writing robust and error-tolerant
# Python code. 1. Specificity in Exception Handling, 2. Use of finally Block 3. Logging Exceptions 4. Raising Exceptions 5. Handling multiple Exceptions 6. Custom Exception classes 7. Avoiding Bare except 8. Exception Chaining
#
# 3.  What is the purpose of the finally block in exception handling?
#
# The finally block in Python is used in conjunction with the try block statement. The finally block is used to write
# code that must be executed regardless of whether the try block generates an error.
#
# 4. What is logging in Python?
#
# Python logging is a module that tracks events that occur while a program is running. It's a built-in feature of Python that helps developers monitor, debug, and troubleshoot their applications.
#
# 5. F What is the significance of the __del__ method in Python?
#
# In Python, the __del__ method, also known as a destructor, is a special method that is called automatically right before an object is about to be removed from memory by the garbage collector, essentially performing any necessary cleanup tasks when an object is no longer referenced by the program
#
# 6. What is the difference between import and from ... import in Python?
#
# When you use the import statement, you are importing the entire module.
# To access a function, class, or variable from that module, you need to refer to it using the module's name.
#
# The from ... import statement allows you to import specific parts (functions, classes, variables) from a module directly into your code, so you don't need to use the module name to access them.
#
# 7.  How can you handle multiple exceptions in Python?
#
# A single except clause can handle many exceptions. In an except clause, we can use a tuple of values to define
# several exceptions.
#
# Using try with finally :
# A single except clause can handle many exceptions. In an except clause, we can use a tuple of values to define
# several exceptions.
#
# The finally block in Python is used in conjunction with the try block statement. The finally block is used to write
# code that must be executed regardless of whether the try block generates an error.
# Syntax :
# try :
# Block of code
# finally:
# this will always be executed
#
# Use try with else:
# Use the else statement in conjunction with If you want to run a specific code only if an exception is not
# produced, use the try block to check if the try block was executed without an exception.
#
# Syntax:
# try:
# Code
# else:
# This code executes when exceptions not occurred
#
# 8. What is the purpose of the with statement when handling files in Python?
#
# The with statement in Python manages resources like files, database connections, and network sockets. It ensures that resources are properly initialized and cleaned up, even if there are exceptions.
#
# 9. What is the difference between multithreading and multiprocessing?
#
# 1. Multithreading:
# Involves running multiple threads within a single process.
# Threads share the same memory space (global variables, data) and resources, which can make communication between them easier and more efficient.
# Best suited for tasks that are I/O-bound (like file handling, network requests) rather than CPU-bound because threads run in the same CPU core and Python's Global Interpreter Lock (GIL) limits true parallel execution for CPU-bound tasks.
#
# 2. Multiprocessing:
# Involves running multiple processes, each with its own memory space and resources.
# Processes are independent and can run on different CPU cores, which allows true parallelism, making it ideal for CPU-bound tasks.
# Since each process has its own memory space, communication between processes can be more complex (using inter-process communication like queues or pipes), but it avoids the GIL limitation.
#
# 10. What are the advantages of using logging in a program?
#
# Logging is a crucial aspect of the coding process since it allows you to keep track of everything that happens
# when you run the code. We can construct custom messages/events to signify different stages of the code by
# logging. Logging facilitates code monitoring, troubleshooting, and debugging.
#
# According to the official Python document, the various severity levels are shown below along with a brief
# description:
# DEBUG - Detailed information, typically of interest only when diagnosing problemsR
# INFO - Confirmation that things are working as expectedR
# WARNING - .An indication that something unexpected happened, or indicative of some problem in the near
# future (e.g. ‘disk space low’). The software is still working as expectedR
# ERROR - Due to a more serious problem, the software has not been able to perform some functionR
# CRITICAL - A serious error, indicating that the program itself may be unable to continue running.
#
# 11. What is memory management in Python?
#
# Python's memory management system allocates and releases memory for Python programs. It uses a combination of techniques, including a private heap, memory pools, and a garbage collector.
#
# Python's memory management system helps programs run efficiently by automatically allocating and deallocating memory. This reduces memory fragmentation and improves allocation performance.
#
# 12. What are the basic steps involved in exception handling in Python?
#
# "try" block: Contains the code that might potentially raise an exception.
#
# "except" block: Handles the exception if it occurs within the "try" block.
#
# Specific exceptions: You can specify the type of exception to catch within the "except" block to handle different errors differently.
#
# "else" block (optional): Executes code only if no exception was raised in the "try" block.
#
#
# "finally" block (optional): Ensures certain code runs regardless of whether an exception occurs, often used for resource cleanup.
#
#
# 13. Why is memory management important in Python?
#
# Python's memory management system helps developers focus more on code logic rather than worrying about manual memory allocation and deallocation.
# Automatic garbage collection ensures memory is freed when it is no longer needed, reducing the risk of memory leaks.
#
# 14. What is the role of try and except in exception handling?
#
# In Python, the try and except blocks are used to handle errors, or exceptions, in your code.
#
# Try block
# Tests a block of code for errors
# The code in the try block is executed first
#
# Except block
# Handles errors that occur in the try block
# You can define multiple except blocks, each for a specific type of error
#
# 15. How does Python's garbage collection system work?
#
# Garbage Collection: Python's garbage collector periodically checks for objects that are no longer in use (e.g., due to circular references) and reclaims their memory.
#
# 16. F What is the purpose of the else block in exception handling?
#
# In exception handling, the "else" block is used to execute a specific section of code only if no exceptions were raised within the "try" block; essentially, it allows you to perform additional operations when the code within the "try" block executes successfully without encountering any errors.
#
# 17. What are the common logging levels in Python?
#
# DEBUG - Detailed information, typically of interest only when diagnosing problems
#
# INFO - Confirmation that things are working as expected
#
# WARNING - .An indication that something unexpected happened, or indicative of some problem in the near
# future (e.g. ‘disk space low’). The software is still working as expected
#
# ERROR - Due to a more serious problem, the software has not been able to perform some function
#
# CRITICAL - A serious error, indicating that the program itself may be unable to continue running.
#
# 18.  What is the difference between os.fork() and multiprocessing in Python?
#
# os.fork() is a low-level, Unix-specific function for creating child processes, offering direct control but limited functionality.
#
# Multiprocessing is a higher-level, cross-platform library for process-based parallelism, providing tools for easier process management and inter-process communication.
#
# 19. What is the importance of closing a file in Python?
#
# Closing a file is important because unless a file is closed it will not show up on the memory. To see see the file, closing the file is required.
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
#
# Difference between file.read() and file.readline() in Python are:
#
# i) file.read() reads the entire file at once, while file.readline() reads one line at a time.
# ii) file.read() returns the full content as a single string, while file.readline() returns a string for each line.
# iii) file.read() is useful for smaller files or when you need to process the entire content, while file.readline() is more memory efficient for large files or when processing one line at a time.
#
# 21. What is the logging module in Python used for?
#
# The logging module in Python is used to track events that occur while a program is running. It can help with debugging, troubleshooting, and monitoring.
#
# 22. What is the os module in Python used for in file handling?
#
# It provides funcanality to interact with operating system
#
# It provides access to system specific parameters and functions such as python path
#
# 23. F What are the challenges associated with memory management in Python?
#
# While automatic memory management simplifies programming, it can also introduce some overhead due to the garbage collection process, potentially affecting performance, especially in large or long-running programs.
#
# 24.  How do you raise an exception manually in Python?
#
# You can define your own exception classes in Python to create custom exceptions. Custom exceptions might
# be handy when you want to raise certain issues in your code that are not handled by the built-in exception
# classes. Here's an example of how to make a custom exception:
# Syntax of Custom Exceptions:
# class CustomException(Exception):
# pass
# try:
# code
#
# 25. Why is it important to use multithreading in certain applications?
#
# Improved Performance: Multithreading can lead to significant performance improvements by allowing parallel
# execution of tasks. Different threads can execute tasks simultaneously, taking advantage of multiple CPU cores
# and reducing overall processing time.
# Responsiveness: In applications with graphical user interfaces (GUIs), multithreading is crucial for maintaining
#
# responsiveness. For example, a user interface can remain responsive while background threads handle time-
# consuming tasks, preventing the application from becoming unresponsive or freezing.
#
# Resource Utilization: Multithreading enables better utilization of system resources. By dividing a program into
# multiple threads, each thread can focus on specific tasks, making efficient use of available resources and
# improving overall system resource utilization.
# Concurrency: Multithreading facilitates the concurrent execution of tasks, allowing different parts of a program
# to run independently. This concurrency can lead to more efficient use of resources and improved application
# performance.
